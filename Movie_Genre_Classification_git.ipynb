# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/train_data.txt',sep=':::',names=['id','label','message'],engine='python')

# %%
df['message']=df['message'].str.lower()
df
# Out:
#                                                  id          label  \
# 1                     Oscar et la dame rose (2009)          drama
# 2                                     Cupid (1997)       thriller
# 3                 Young, Wild and Wonderful (1980)          adult
# 4                            The Secret Sin (1915)          drama
# 5                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54210                              "Bonino" (1953)         comedy
# 54211                  Dead Girls Don't Cry (????)         horror
# 54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54213                     Make Your Own Bed (1944)         comedy
# 54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                                  message
# 1       listening in to a conversation between his do...
# 2       a brother and sister with a past incestuous r...
# ...

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk import sent_tokenize,word_tokenize
from sklearn.preprocessing import LabelEncoder
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Removing Punctuation

# %%
import string
def remove_punctuation(text):
  punctuations=(string.punctuation)
  return text.translate(str.maketrans('','',punctuations))

# %%
df['message']=df['message'].apply(remove_punctuation)

# %% [markdown]
# Stopwords removal

# %%
from nltk.corpus import stopwords
def stopwords_remove(text):
  stop_words=set(stopwords.words('english'))
  return ' '.join([char for char in text.split() if char not in stop_words])

# %%
df['message']=df['message'].apply(stopwords_remove)

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import SVC

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

# %%
pipe=Pipeline([
    ('bow',CountVectorizer(max_features=3000)),
    ('classifer',BernoulliNB())
])

# %%
df['message'].shape
# Out:
# (54214,)

# %%
df['label'].shape
# Out:
# (54214,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y1_test=train_test_split(df['message'],df['label'])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(max_features=3000)),
#                 ('classifer', BernoulliNB())])

# %%
pred=pipe.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
pred=pd.DataFrame(pred)
pred.head()
# Out:
#                0
# 0         drama
# 1           war
# 2         drama
# 3        horror
# 4   documentary

# %%
print(classification_report(y1_test,pred,zero_division=0))
# Out:
#                precision    recall  f1-score   support
#
#       action        0.35      0.41      0.38       335
#        adult        0.43      0.46      0.45       149
#    adventure        0.20      0.17      0.18       181
#    animation        0.42      0.26      0.32       128
#    biography        0.00      0.00      0.00        50
#       comedy        0.48      0.52      0.50      1904
#        crime        0.17      0.15      0.16       114
#  documentary        0.74      0.66      0.70      3184
#        drama        0.65      0.53      0.58      3454
#       family        0.29      0.15      0.20       207
#      fantasy        0.20      0.12      0.15        86
#    game-show        0.68      0.67      0.67        42
#      history        0.02      0.02      0.02        61
#       horror        0.59      0.56      0.58       532
#        music        0.35      0.72      0.47       178
#      musical        0.12      0.07      0.09        70
# ...
